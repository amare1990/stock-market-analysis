# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# %%
from load_data import load_data
df = load_data("/home/am/Documents/Software Development/10_Academy Training/week1/Data/raw_analyst_ratings.csv")

# %%
import matplotlib.pyplot as plt
from publisher_contribution import analyze_publisher_contribution
# Analyze publisher contribution
publisher_contribution = analyze_publisher_contribution(df, publisher_column='publisher')
save_path = "plots/publishers_contribution.png"
    
# Ensure the 'plots' directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the plot to the specified path
plt.savefig(save_path)
# Out:
# /home/am/Documents/Software Development/10_Academy Training/week1/stock-market-analysis/scripts/publisher_contribution.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=publisher_counts.head(10), x=publisher_column, y='publication_count', palette='viridis')
